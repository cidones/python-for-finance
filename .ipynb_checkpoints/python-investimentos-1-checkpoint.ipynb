# %% [markdown]
# # 0.0. Imports

# %%
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt
import pandas_datareader as web
import yfinance          as yf

yf.pdr_override()
# %matplotlib inline

# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22415 sha256=5c93e1f91c96c2b5934c4558b0ecbfac4ad286ea4101be032813b8d29ad411cd
#   Stored in directory: C:\Users\FERNAN~1.ROC\AppData\Local\Temp\pip-ephem-wheel-cache-5cflvx5p\wheels\28\79\3c\08a301b673366fe664fe2853e136eb2acc1bb752045c11c6a1
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8374 sha256=1fcc2b5b3b75e4f407fee012dc76f8a50ca0b83f2b21c581ad87b96a723213b3
#   Stored in directory: C:\Users\FERNAN~1.ROC\AppData\Local\Temp\pip-ephem-wheel-cache-5cflvx5p\wheels\ae\25\47\4d68431a7ec1b6c4b5233365934b74c1d4e665bf5f968d363a
# Successfully built yfinance multitasking
# ...

# %% [markdown]
# # 1.0. Market Data

# %%
ibov = web.get_data_yahoo('^BVSP')

# %%
ibov.tail()
# Out:
#                     High         Low          Open         Close      Volume  \
# Date
# 2020-06-04  94132.000000  92221.0000  92993.000000  93829.000000  11488000.0
# 2020-06-05  97356.000000  93839.0000  93839.000000  94637.000000  13320300.0
# 2020-06-08  97693.000000  94635.0000  94640.000000  97645.000000  11096500.0
# 2020-06-09  97644.000000  95386.0000  97644.000000  96747.000000  11278800.0
# 2020-06-10  97645.851562  94664.8125  96747.320312  94685.976562         0.0
#
#                Adj Close
# Date
# 2020-06-04  93829.000000
# 2020-06-05  94637.000000
# 2020-06-08  97645.000000
# 2020-06-09  96747.000000
# 2020-06-10  94685.976562

# %%
ibov_slice = ibov[(ibov.index.year >=2010) & (ibov.index.year <= 2020)]
ibov_slice['Close'].plot();
ibov_slice['Close'].rolling(21).mean().plot(label="MM21");
ibov_slice['Close'].rolling(200).mean().plot(label="MM21");
plt.legend()

# %%
ibov_slice = ibov[ibov.index.month == 12]
ibov_slice.tail(50)
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 2017-12-12   73814.0   71798.0   72800.0   73814.0  2956100.0    73814.0
# 2017-12-13   74622.0   72569.0   73827.0   72914.0  4494700.0    72914.0
# 2017-12-14   72913.0   71969.0   72913.0   72429.0  3491800.0    72429.0
# 2017-12-15   73069.0   72277.0   72428.0   72608.0  4659500.0    72608.0
# 2017-12-18   73519.0   72621.0   72621.0   73115.0  3202900.0    73115.0
# 2017-12-19   73139.0   72347.0   73122.0   72680.0  2351600.0    72680.0
# 2017-12-20   73492.0   72680.0   72680.0   73367.0  2219600.0    73367.0
# 2017-12-21   75133.0   73265.0   73367.0   75133.0  3056400.0    75133.0
# 2017-12-22   75227.0   74623.0   75128.0   75187.0  1906900.0    75187.0
# 2017-12-26   75758.0   74924.0   75187.0   75688.0  1579700.0    75688.0
# 2017-12-27   76293.0   75708.0   75708.0   76073.0  1792200.0    76073.0
# 2017-12-28   76437.0   76077.0   76077.0   76402.0  2083000.0    76402.0
# ...

# %%
ibov = web.get_data_yahoo('VALE3.SA', start='2016-01-01', end='2020-06-01')

# %%
ibov.head()
# Out:
#              High    Low   Open  Close     Volume  Adj Close
# Date
# 2016-01-04  12.98  12.48  12.49  12.69  4587900.0  11.309562
# 2016-01-05  12.84  12.41  12.67  12.52  2693500.0  11.158054
# 2016-01-06  12.11  11.59  12.08  11.60  6758900.0  10.338134
# 2016-01-07  11.37  10.88  11.26  10.91  6450400.0   9.723193
# 2016-01-08  11.25  10.54  11.07  10.54  4429400.0   9.393443
